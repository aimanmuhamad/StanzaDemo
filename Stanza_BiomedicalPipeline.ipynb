# %%
pip3 install stanza
# Out:
# Collecting stanza
#   Downloading stanza-1.4.0-py3-none-any.whl (574 kB)
#      |████████████████████████████████| 574 kB 7.3 MB/s
# Collecting emoji
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      |████████████████████████████████| 175 kB 48.5 MB/s
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from stanza) (1.11.0+cu113)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from stanza) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from stanza) (1.21.6)
# Collecting transformers
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 48.9 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from stanza) (4.64.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from stanza) (2.23.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from stanza) (3.17.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.0->stanza) (4.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (3.0.4)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 6.4 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 44.5 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->stanza) (2019.12.20)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 71.1 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers->stanza) (3.6.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers->stanza) (4.11.3)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 37.3 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers->stanza) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers->stanza) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers->stanza) (3.8.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->stanza) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->stanza) (1.1.0)
# Building wheels for collected packages: emoji, sacremoses
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=55bb43986f79b465abefd3bf602b1dfe06816c2c3054cf09949fa67422591702
#   Stored in directory: /root/.cache/pip/wheels/8a/4e/b6/57b01db010d17ef6ea9b40300af725ef3e210cb1acfb7ac8b6
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=1694f7f9117ae8bbece0083a0afdaf895a9ff78373109c0179ef967695cb7861
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built emoji sacremoses
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers, emoji, stanza
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed emoji-1.7.0 huggingface-hub-0.5.1 pyyaml-6.0 sacremoses-0.0.53 stanza-1.4.0 tokenizers-0.12.1 transformers-4.18.0

# %%
import stanza

# %%
# download and initialize the CRAFT pipeline
stanza.download('en', package='craft')
nlp = stanza.Pipeline('en', package='craft')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.0.json:   0%|   …
# 2022-05-04 06:41:07 INFO: Downloading these customized packages for language: en (English)...
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | craft   |
# | pos       | craft   |
# | lemma     | craft   |
# | depparse  | craft   |
# | pretrain  | craft   |
# =======================
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.0/models/tokenize/craft.pt:   0%|       …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.0/models/pos/craft.pt:   0%|          | …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.0/models/lemma/craft.pt:   0%|          …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.0/models/depparse/craft.pt:   0%|       …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.0/models/pretrain/craft.pt:   0%|       …
# 2022-05-04 06:41:18 INFO: Finished downloading models and saved to /root/stanza_resources.
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.0.json:   0%|   …
# 2022-05-04 06:41:18 INFO: Loading these models for language: en (English):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | craft   |
# | pos       | craft   |
# | lemma     | craft   |
# | depparse  | craft   |
# =======================
#
# 2022-05-04 06:41:18 INFO: Use device: cpu
# 2022-05-04 06:41:18 INFO: Loading: tokenize
# 2022-05-04 06:41:18 INFO: Loading: pos
# 2022-05-04 06:41:18 INFO: Loading: lemma
# 2022-05-04 06:41:19 INFO: Loading: depparse
# 2022-05-04 06:41:19 INFO: Done loading processors!

# %%
# annotate example text
doc = nlp('A single-cell transcriptomic atlas characterizes ageing tissues in the mouse.')

# %%
# print out dependency tree
doc.sentences[0].print_dependencies()
# Out:
# ('A', 6, 'det')
# ('single', 4, 'amod')
# ('-', 4, 'punct')
# ('cell', 6, 'compound')
# ('transcriptomic', 6, 'amod')
# ('atlas', 7, 'nsubj')
# ('characterizes', 0, 'root')
# ('ageing', 9, 'compound')
# ('tissues', 7, 'obj')
# ('in', 12, 'case')
# ('the', 12, 'det')
# ('mouse', 7, 'obl')
# ('.', 7, 'punct')

# %%
# download and initialize a mimic pipeline with an i2b2 NER model
stanza.download('en', package='mimic', processors={'ner': 'i2b2'})
nlp = stanza.Pipeline('en', package='mimic', processors={'ner': 'i2b2'})
# annotate clinical text
doc = nlp('The patient had a sore throat and was treated with Cepacol lozenges.')
# print out all entities
for ent in doc.entities:
    print(f'{ent.text}\t{ent.type}')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.0.json:   0%|   …
# 2022-05-04 06:43:00 INFO: Downloading these customized packages for language: en (English)...
# =============================
# | Processor       | Package |
# -----------------------------
# | tokenize        | mimic   |
# | pos             | mimic   |
# | lemma           | mimic   |
# | depparse        | mimic   |
# | ner             | i2b2    |
# | backward_charlm | mimic   |
# | pretrain        | mimic   |
# | forward_charlm  | mimic   |
# =============================
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.0/models/tokenize/mimic.pt:   0%|       …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.0/models/pos/mimic.pt:   0%|          | …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.0/models/lemma/mimic.pt:   0%|          …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.0/models/depparse/mimic.pt:   0%|       …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.0/models/ner/i2b2.pt:   0%|          | 0…
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.0/models/backward_charlm/mimic.pt:   0%|…
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.0/models/pretrain/mimic.pt:   0%|       …
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.0/models/forward_charlm/mimic.pt:   0%| …
# 2022-05-04 06:43:19 INFO: Finished downloading models and saved to /root/stanza_resources.
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.0.json:   0%|   …
# 2022-05-04 06:43:20 INFO: Loading these models for language: en (English):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | mimic   |
# | pos       | mimic   |
# | lemma     | mimic   |
# | depparse  | mimic   |
# | ner       | i2b2    |
# =======================
#
# 2022-05-04 06:43:20 INFO: Use device: cpu
# 2022-05-04 06:43:20 INFO: Loading: tokenize
# 2022-05-04 06:43:20 INFO: Loading: pos
# 2022-05-04 06:43:20 INFO: Loading: lemma
# 2022-05-04 06:43:20 INFO: Loading: depparse
# 2022-05-04 06:43:20 INFO: Loading: ner
# 2022-05-04 06:43:21 INFO: Done loading processors!
# a sore throat	PROBLEM
# Cepacol lozenges	TREATMENT

# %%
stanza.download('en', package='mimic', processors={'ner': 'anatem'})
nlp = stanza.Pipeline('en', package='mimic', processors={'ner': 'anatem'})
# annotate clinical text
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.0.json:   0%|   …
# 2022-05-04 06:43:21 INFO: Downloading these customized packages for language: en (English)...
# =============================
# | Processor       | Package |
# -----------------------------
# | tokenize        | mimic   |
# | pos             | mimic   |
# | lemma           | mimic   |
# | depparse        | mimic   |
# | ner             | anatem  |
# | forward_charlm  | pubmed  |
# | pretrain        | mimic   |
# | backward_charlm | pubmed  |
# =============================
#
# 2022-05-04 06:43:21 INFO: File exists: /root/stanza_resources/en/tokenize/mimic.pt
# 2022-05-04 06:43:21 INFO: File exists: /root/stanza_resources/en/pos/mimic.pt
# 2022-05-04 06:43:21 INFO: File exists: /root/stanza_resources/en/lemma/mimic.pt
# 2022-05-04 06:43:22 INFO: File exists: /root/stanza_resources/en/depparse/mimic.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.0/models/ner/anatem.pt:   0%|          |…
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.0/models/forward_charlm/pubmed.pt:   0%|…
# 2022-05-04 06:43:24 INFO: File exists: /root/stanza_resources/en/pretrain/mimic.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.0/models/backward_charlm/pubmed.pt:   0%…
# 2022-05-04 06:43:25 INFO: Finished downloading models and saved to /root/stanza_resources.
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.0.json:   0%|   …
# 2022-05-04 06:43:26 INFO: Loading these models for language: en (English):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | mimic   |
# | pos       | mimic   |
# | lemma     | mimic   |
# | depparse  | mimic   |
# | ner       | anatem  |
# =======================
#
# 2022-05-04 06:43:26 INFO: Use device: cpu
# 2022-05-04 06:43:26 INFO: Loading: tokenize
# 2022-05-04 06:43:26 INFO: Loading: pos
# 2022-05-04 06:43:26 INFO: Loading: lemma
# 2022-05-04 06:43:26 INFO: Loading: depparse
# 2022-05-04 06:43:27 INFO: Loading: ner
# 2022-05-04 06:43:27 INFO: Done loading processors!

# %%
doc = nlp("Selegiline - induced postural hypotension in Parkinson ' s disease : a longitudinal study on the effects of drug withdrawal.The aims of this study were to confirm our previous findings in a separate cohort of patients and to determine the time course of the cardiovascular consequences of stopping selegiline in the expectation that this might shed light on the mechanisms by which the drug causes orthostatic hypotension")
# print out all entities
for ent in doc.entities:
    print(f'{ent.text}\t{ent.type}')
# Out:
# cardiovascular	ANATOMY

# %%
doc = nlp("A 22-year-old man presented with progressive neurologic decline. A year before presentation, painless vision loss had occurred in the left eye, followed by the right eye. During the next 4 to 6 months, diffuse numbness, limb stiffness, whole-body weakness, and urinary incontinence had developed.")
# print out all entities
for ent in doc.entities:
    print(f'{ent.text}\t{ent.type}')
# Out:
# neurologic	ANATOMY
# left eye	ANATOMY
# right eye	ANATOMY
# limb	ANATOMY
# body	ANATOMY
# urinary	ANATOMY

# %%
nlp = stanza.Pipeline('en', package='mimic', processors={'ner':'i2b2'})
doc = nlp("A 22-year-old man presented with progressive neurologic decline. A year before presentation, painless vision loss had occurred in the left eye, followed by the right eye. During the next 4 to 6 months, diffuse numbness, limb stiffness, whole-body weakness, and urinary incontinence had developed.")
# print out all entities
for ent in doc.entities:
    print(f'{ent.text}\t{ent.type}')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.0.json:   0%|   …
# 2022-05-04 06:43:30 INFO: Loading these models for language: en (English):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | mimic   |
# | pos       | mimic   |
# | lemma     | mimic   |
# | depparse  | mimic   |
# | ner       | i2b2    |
# =======================
#
# 2022-05-04 06:43:30 INFO: Use device: cpu
# 2022-05-04 06:43:30 INFO: Loading: tokenize
# 2022-05-04 06:43:30 INFO: Loading: pos
# 2022-05-04 06:43:30 INFO: Loading: lemma
# 2022-05-04 06:43:31 INFO: Loading: depparse
# 2022-05-04 06:43:31 INFO: Loading: ner
# 2022-05-04 06:43:31 INFO: Done loading processors!
# progressive neurologic decline	PROBLEM
# painless vision loss	PROBLEM
# diffuse numbness	PROBLEM
# limb stiffness	PROBLEM
# whole-body weakness	PROBLEM
# urinary incontinence	PROBLEM

# %%
nlp = stanza.Pipeline('en', package='mimic', processors={'ner':'anatem'})
doc = nlp("A 70-year-old man with bipolar disorder was evaluated because of depressed mood, suicidal ideation, and gait disturbance. One month earlier, he had been voluntarily hospitalized for depression. In the following weeks, he had worsening gait instability and urinary incontinence. Diagnostic tests were performed.")
# print out all entities
for ent in doc.entities:
    print(f'{ent.text}\t{ent.type}')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.0.json:   0%|   …
# 2022-05-04 06:43:33 INFO: Loading these models for language: en (English):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | mimic   |
# | pos       | mimic   |
# | lemma     | mimic   |
# | depparse  | mimic   |
# | ner       | anatem  |
# =======================
#
# 2022-05-04 06:43:33 INFO: Use device: cpu
# 2022-05-04 06:43:33 INFO: Loading: tokenize
# 2022-05-04 06:43:33 INFO: Loading: pos
# 2022-05-04 06:43:33 INFO: Loading: lemma
# 2022-05-04 06:43:33 INFO: Loading: depparse
# 2022-05-04 06:43:34 INFO: Loading: ner
# 2022-05-04 06:43:34 INFO: Done loading processors!
# urinary	ANATOMY

# %%
nlp = stanza.Pipeline('en', package='mimic', processors={'ner':'i2b2'})
doc = nlp("A 70-year-old man with bipolar disorder was evaluated because of depressed mood, suicidal ideation, and gait disturbance. One month earlier, he had been voluntarily hospitalized for depression. In the following weeks, he had worsening gait instability and urinary incontinence. Diagnostic tests were performed.")
# print out all entities
for ent in doc.entities:
    print(f'{ent.text}\t{ent.type}')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.0.json:   0%|   …
# 2022-05-04 06:43:36 INFO: Loading these models for language: en (English):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | mimic   |
# | pos       | mimic   |
# | lemma     | mimic   |
# | depparse  | mimic   |
# | ner       | i2b2    |
# =======================
#
# 2022-05-04 06:43:36 INFO: Use device: cpu
# 2022-05-04 06:43:36 INFO: Loading: tokenize
# 2022-05-04 06:43:36 INFO: Loading: pos
# 2022-05-04 06:43:36 INFO: Loading: lemma
# 2022-05-04 06:43:36 INFO: Loading: depparse
# 2022-05-04 06:43:37 INFO: Loading: ner
# 2022-05-04 06:43:37 INFO: Done loading processors!
# bipolar disorder	PROBLEM
# depressed mood	PROBLEM
# suicidal ideation	PROBLEM
# gait disturbance	PROBLEM
# depression	PROBLEM
# worsening gait instability	PROBLEM
# urinary incontinence	PROBLEM
# Diagnostic tests	TEST
